# %%
import pandas as pd

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")

# %%
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")

# %%
customers = pd.read_csv("Restaurant - Customers.csv")

# %%
foods = pd.read_csv("Restaurant - Foods.csv")

# %%
satisfaction = pd.read_csv("Restaurant - Week 1 Satisfaction.csv")

# %%
len(foods)
# Out:
# 10

# %%
len(week1)
# Out:
# 250

# %%
len(week2)
# Out:
# 250

# %%
both_weeks = pd.concat([week1, week2])

# %%
len(both_weeks)
# Out:
# 500

# %%
week1.append(week2)
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# 5            213        8
# 6            600        1
# 7            503        5
# 8             71        3
# 9            174        3
# 10           961        9
# 11           966        5
# 12           641        4
# 13           288        2
# 14           149        4
# 15           954        2
# 16           147        9
# 17           155        1
# 18           550        6
# 19           101        7
# 20           549        6
# 21            75        6
# 22            78        7
# 23           514        5
# 24           833        7
# 25           329        8
# 26           586       10
# 27           341        1
# 28           519       10
# 29           680        9
# ..           ...      ...
# 220          495        2
# 221          794        6
# 222          734       10
# 223          540        3
# 224          735        2
# 225          940        8
# 226          571        7
# 227          888        2
# 228          664        6
# 229          343        7
# 230          143        4
# 231          505        3
# 232           54        8
# 233          959        2
# 234          367        8
# 235          883        8
# 236          251        9
# 237          855        4
# 238          233        3
# 239          559       10
# 240          734        1
# 241          677        3
# 242          276        4
# 243           45        8
# 244          945        4
# 245          783       10
# 246          556       10
# 247          547        9
# 248          252        9
# 249          249        6
#
# [500 rows x 2 columns]

# %%
len(week1)
# Out:
# 250
